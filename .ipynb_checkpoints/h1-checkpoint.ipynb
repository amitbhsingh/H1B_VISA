# %% [markdown]
# # Objective: Our main objective is to predict from if an Applicant will be issued visa based on given information by them

# %% [markdown]
# # Overview
# #### RFE Request for extra document
# ### Are we trying to predict pre or post lottery

# %% [markdown]
# #### Snapshot of Data Description for H1B_VISA
# #### Reference: https://www.foreignlaborcert.doleta.gov/docs/Performance_Data/Disclosure/FY15-FY16/H-1B_FY16_Record_Layout.pdf
#
#    # ![title](DataDesc1.png)
#    # ![title](DataDesc2.png)

# %% [markdown]
# # More information related to data

# %%
from IPython.core.display import display, HTML
display(HTML("""<a href="https://www.foreignlaborcert.doleta.gov/pdf/PerformanceData/2017/H-1B_Selected_Statistics_FY2017.pdf"> Click Here For Selected Statistics</a>"""))
# Out:
# <a href="https://www.foreignlaborcert.doleta.gov/pdf/PerformanceData/2017/H-1B_Selected_Statistics_FY2017.pdf"> Click Here For Selected Statistics</a>

# %% [markdown]
# #### Refer to the link below for brief overview of H1B visa
# #### https://www.h1base.com/visa/work/H1B%20Visa%20Overview/ref/1164/

# %% [markdown]
# #### This is self learning project for immigration data

# %% [markdown]
# #### Installing required packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importing training and test set

# %%
train=pd.read_csv("TrainH1BLast.csv")
test=pd.read_csv("TestH1BLast No Y values.csv")

# %% [markdown]
# #### Glimpse of the dataset

# %%
train.head()
# Out:
#    Ob CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS  \
# 0   1      DENIED      5/25/2017     5/25/2017       H-1B
# 1   2      DENIED      11/4/2014     8/16/2017       H-1B
# 2   3      DENIED      10/6/2016    10/13/2016       H-1B
# 3   4      DENIED      8/14/2017     8/14/2017       H-1B
# 4   5      DENIED      4/20/2017     4/20/2017       H-1B
#
#   EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE                   EMPLOYER_NAME  \
# 0             9/21/2017           9/20/2020                 VERTISYSTEM INC
# 1             12/8/2014           12/7/2017                     GOOGLE INC.
# 2            11/11/2016          11/10/2019  KIMBERLY-CLARK WORLDWIDE, INC.
# 3             8/14/2017           8/14/2020                    EMBTEL, INC.
# 4            10/16/2017          10/15/2020        SPACE TIME INSIGHT, INC.
#
#   EMPLOYER_BUSINESS_DBA           EMPLOYER_ADDRESS        ...          \
# 0                   NaN   39300 CIVIC CENTER DRIVE        ...
# 1                   NaN  1600 AMPHITHEATRE PARKWAY        ...
# 2                   NaN         2001 MARATHON AVE.        ...
# 3                   NaN  39159 PASEO PADRE PARKWAY        ...
# 4                   NaN           1850 GATEWAY DR.        ...
#
#   H1B_DEPENDENT WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE  \
# 0             Y                N           Y               Y
# 1             N                N         NaN             NaN
# 2             N                N         NaN             NaN
# 3             Y                N           Y               Y
# 4             N                N         NaN             NaN
#
#   PUBLIC_DISCLOSURE_LOCATION  WORKSITE_CITY WORKSITE_COUNTY WORKSITE_STATE  \
# 0                        NaN      SUNNYVALE     SANTA CLARA             CA
# 1                        NaN  MOUNTAIN VIEW     SANTA CLARA             CA
# 2                        NaN         NEENAH       WINNEBAGO             WI
# 3                        NaN      CHARLOTTE     MECKLENBURG             NC
# 4                        NaN        MEMPHIS          SHELBY             TN
#
#   WORKSITE_POSTAL_CODE ORIGINAL_CERT_DATE
# 0                94085                NaN
# 1                94043                NaN
# 2                54956                NaN
# 3                28202                NaN
# 4                38125                NaN
#
# [5 rows x 52 columns]

# %%
train.describe()
# Out:
#                 Ob     NAICS_CODE  TOTAL_WORKERS  NEW_EMPLOYMENT  \
# count  4918.000000    4918.000000    4918.000000     4918.000000
# mean   2459.500000  438568.020130       1.699268        0.766165
# std    1419.848642  204422.510048       3.857599        2.605320
# min       1.000000    2122.000000       1.000000        0.000000
# 25%    1230.250000  424240.000000       1.000000        0.000000
# 50%    2459.500000  541511.000000       1.000000        0.000000
# 75%    3688.750000  541511.000000       1.000000        1.000000
# max    4918.000000  926130.000000      75.000000       75.000000
#
#        CONTINUED_EMPLOYMENT  CHANGE_PREVIOUS_EMPLOYMENT  \
# count           4918.000000                 4918.000000
# mean               0.296869                    0.110411
# std                1.166491                    0.943281
# min                0.000000                    0.000000
# 25%                0.000000                    0.000000
# 50%                0.000000                    0.000000
# 75%                0.000000                    0.000000
# max               50.000000                   50.000000
#
#        NEW_CONCURRENT_EMPLOYMENT  CHANGE_EMPLOYER  AMENDED_PETITION  \
# count                4918.000000      4918.000000       4918.000000
# mean                    0.008337         0.231802          0.269622
# std                     0.105433         0.836398          1.224660
# min                     0.000000         0.000000          0.000000
# 25%                     0.000000         0.000000          0.000000
# 50%                     0.000000         0.000000          0.000000
# 75%                     0.000000         0.000000          0.000000
# max                     2.000000        15.000000         15.000000
#
#        PREVAILING_WAGE  PW_SOURCE_YEAR  WAGE_RATE_OF_PAY_FROM  \
# count      4918.000000     4915.000000            4918.000000
# mean      71229.232574     2016.120041           82009.587885
# std       34648.534323        0.742782           48850.029727
# min           0.000000     2001.000000               0.000000
# 25%       55895.000000     2016.000000           61922.000000
# 50%       69628.000000     2016.000000           75795.000000
# 75%       88067.000000     2017.000000          100000.000000
# max      336000.000000     2017.000000          850000.000000
#
#        WAGE_RATE_OF_PAY_TO  PUBLIC_DISCLOSURE_LOCATION
# count          4918.000000                         0.0
# mean          25095.936682                         NaN
# std           53984.001841                         NaN
# min               0.000000                         NaN
# 25%               0.000000                         NaN
# 50%               0.000000                         NaN
# 75%               0.000000                         NaN
# max          804391.000000                         NaN

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4918 entries, 0 to 4917
# Data columns (total 52 columns):
# Ob                             4918 non-null int64
# CASE_STATUS                    4918 non-null object
# CASE_SUBMITTED                 4918 non-null object
# DECISION_DATE                  4918 non-null object
# VISA_CLASS                     4918 non-null object
# EMPLOYMENT_START_DATE          4918 non-null object
# EMPLOYMENT_END_DATE            4918 non-null object
# EMPLOYER_NAME                  4918 non-null object
# EMPLOYER_BUSINESS_DBA          375 non-null object
# EMPLOYER_ADDRESS               4918 non-null object
# EMPLOYER_CITY                  4918 non-null object
# EMPLOYER_STATE                 4918 non-null object
# EMPLOYER_POSTAL_CODE           4918 non-null object
# EMPLOYER_COUNTRY               4084 non-null object
# EMPLOYER_PROVINCE              47 non-null object
# EMPLOYER_PHONE                 4084 non-null object
# EMPLOYER_PHONE_EXT             207 non-null object
# AGENT_REPRESENTING_EMPLOYER    4084 non-null object
# AGENT_ATTORNEY_NAME            4918 non-null object
# AGENT_ATTORNEY_CITY            2683 non-null object
# AGENT_ATTORNEY_STATE           2601 non-null object
# JOB_TITLE                      4918 non-null object
# SOC_CODE                       4918 non-null object
# SOC_NAME                       4918 non-null object
# NAICS_CODE                     4918 non-null int64
# TOTAL_WORKERS                  4918 non-null int64
# NEW_EMPLOYMENT                 4918 non-null int64
# CONTINUED_EMPLOYMENT           4918 non-null int64
# CHANGE_PREVIOUS_EMPLOYMENT     4918 non-null int64
# NEW_CONCURRENT_EMPLOYMENT      4918 non-null int64
# CHANGE_EMPLOYER                4918 non-null int64
# AMENDED_PETITION               4918 non-null int64
# FULL_TIME_POSITION             4918 non-null object
# PREVAILING_WAGE                4918 non-null float64
# PW_UNIT_OF_PAY                 4915 non-null object
# PW_WAGE_LEVEL                  3831 non-null object
# PW_SOURCE                      4916 non-null object
# PW_SOURCE_YEAR                 4915 non-null float64
# PW_SOURCE_OTHER                4779 non-null object
# WAGE_RATE_OF_PAY_FROM          4918 non-null float64
# WAGE_RATE_OF_PAY_TO            4918 non-null float64
# WAGE_UNIT_OF_PAY               4917 non-null object
# H1B_DEPENDENT                  4769 non-null object
# WILLFUL_VIOLATOR               4769 non-null object
# SUPPORT_H1B                    1657 non-null object
# LABOR_CON_AGREE                2080 non-null object
# PUBLIC_DISCLOSURE_LOCATION     0 non-null float64
# WORKSITE_CITY                  4918 non-null object
# WORKSITE_COUNTY                4910 non-null object
# WORKSITE_STATE                 4917 non-null object
# WORKSITE_POSTAL_CODE           4918 non-null object
# ORIGINAL_CERT_DATE             229 non-null object
# dtypes: float64(5), int64(9), object(38)
# memory usage: 2.0+ MB

# %%
train['CASE_STATUS'].unique()
# Out:
# array(['DENIED', 'CERTIFIED'], dtype=object)

# %%
train['VISA_CLASS'].unique()
# Type of visa
# Out:
# array(['H-1B', 'E-3 Australian', 'H-1B1 Singapore', 'H-1B1 Chile'],
#       dtype=object)

# %% [markdown]
# ##### Name of the columns

# %%
columnnames=train.columns

# %%
# Here I have made a copy of column names in for the columns in dataset 
columnnames
# Out:
# Index(['Ob', 'CASE_STATUS', 'CASE_SUBMITTED', 'DECISION_DATE', 'VISA_CLASS',
#        'EMPLOYMENT_START_DATE', 'EMPLOYMENT_END_DATE', 'EMPLOYER_NAME',
#        'EMPLOYER_BUSINESS_DBA', 'EMPLOYER_ADDRESS', 'EMPLOYER_CITY',
#        'EMPLOYER_STATE', 'EMPLOYER_POSTAL_CODE', 'EMPLOYER_COUNTRY',
#        'EMPLOYER_PROVINCE', 'EMPLOYER_PHONE', 'EMPLOYER_PHONE_EXT',
#        'AGENT_REPRESENTING_EMPLOYER', 'AGENT_ATTORNEY_NAME',
#        'AGENT_ATTORNEY_CITY', 'AGENT_ATTORNEY_STATE', 'JOB_TITLE', 'SOC_CODE',
#        'SOC_NAME', 'NAICS_CODE', 'TOTAL_WORKERS', 'NEW_EMPLOYMENT',
#        'CONTINUED_EMPLOYMENT', 'CHANGE_PREVIOUS_EMPLOYMENT',
#        'NEW_CONCURRENT_EMPLOYMENT', 'CHANGE_EMPLOYER', 'AMENDED_PETITION',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'PW_UNIT_OF_PAY',
#        'PW_WAGE_LEVEL', 'PW_SOURCE', 'PW_SOURCE_YEAR', 'PW_SOURCE_OTHER',
#        'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY',
#        'H1B_DEPENDENT', 'WILLFUL_VIOLATOR', 'SUPPORT_H1B', 'LABOR_CON_AGREE',
#        'PUBLIC_DISCLOSURE_LOCATION', 'WORKSITE_CITY', 'WORKSITE_COUNTY',
#        'WORKSITE_STATE', 'WORKSITE_POSTAL_CODE', 'ORIGINAL_CERT_DATE'],
#       dtype='object')

# %%
len(train.columns)
# Out:
# 52

# %%
test.head()
# Out:
#    Ob CASE_SUBMITTED DECISION_DATE      VISA_CLASS EMPLOYMENT_START_DATE  \
# 0   1      7/12/2017     7/13/2017            H-1B             12/1/2017
# 1   2      2/10/2017     2/14/2017            H-1B             2/27/2017
# 2   3      3/16/2017     3/21/2017            H-1B              6/1/2017
# 3   4      3/25/2017     3/28/2017            H-1B             3/27/2017
# 4   5      1/11/2017     1/12/2017  E-3 Australian              3/1/2017
#
#   EMPLOYMENT_END_DATE                    EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 0          11/30/2020           8SIANMEDIA CORPORATION                   NaN
# 1           2/26/2020            COROS WEARABLES, INC.                   NaN
# 2           5/31/2020      RELIANT MEDICAL GROUP, INC.                   NaN
# 3           3/26/2020            MYTHRI CONSULTING LLC                   NaN
# 4            3/1/2019  MARYAM NASSIR ZADEH CORPORATION   MARYAM NASSIR ZADEH
#
#        EMPLOYER_ADDRESS EMPLOYER_CITY        ...         H1B_DEPENDENT  \
# 0    25 E FOOTHILL BLVD       ARCADIA        ...                     N
# 1   3310 NOBLE POND WAY    WOODBRIDGE        ...                     N
# 2      100 FRONT STREET     WORCESTER        ...                     N
# 3  1721 W PLANO PARKWAY         PLANO        ...                     Y
# 4        123 NORFOLK ST      NEW YORK        ...                   NaN
#
#   WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE PUBLIC_DISCLOSURE_LOCATION  \
# 0                N         NaN               Y                        NaN
# 1                N         NaN               Y                        NaN
# 2                N         NaN             NaN                        NaN
# 3                N           Y               Y                        NaN
# 4              NaN         NaN             NaN                        NaN
#
#    WORKSITE_CITY WORKSITE_COUNTY WORKSITE_STATE WORKSITE_POSTAL_CODE  \
# 0        ARCADIA     LOS ANGELES             CA                91006
# 1     WOODBRIDGE  PRINCE WILLIAM             VA                22193
# 2      WORCESTER       WORCESTER             MA                 1608
# 3          PLANO          COLLIN             TX                75075
# 4       NEW YORK        NEW YORK             NY                10002
#
#   ORIGINAL_CERT_DATE
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 51 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2093 entries, 0 to 2092
# Data columns (total 51 columns):
# Ob                             2093 non-null int64
# CASE_SUBMITTED                 2093 non-null object
# DECISION_DATE                  2093 non-null object
# VISA_CLASS                     2093 non-null object
# EMPLOYMENT_START_DATE          2092 non-null object
# EMPLOYMENT_END_DATE            2091 non-null object
# EMPLOYER_NAME                  2092 non-null object
# EMPLOYER_BUSINESS_DBA          162 non-null object
# EMPLOYER_ADDRESS               2093 non-null object
# EMPLOYER_CITY                  2093 non-null object
# EMPLOYER_STATE                 2093 non-null object
# EMPLOYER_POSTAL_CODE           2093 non-null object
# EMPLOYER_COUNTRY               1768 non-null object
# EMPLOYER_PROVINCE              15 non-null object
# EMPLOYER_PHONE                 1768 non-null object
# EMPLOYER_PHONE_EXT             96 non-null float64
# AGENT_REPRESENTING_EMPLOYER    1768 non-null object
# AGENT_ATTORNEY_NAME            2093 non-null object
# AGENT_ATTORNEY_CITY            1161 non-null object
# AGENT_ATTORNEY_STATE           1121 non-null object
# JOB_TITLE                      2093 non-null object
# SOC_CODE                       2093 non-null object
# SOC_NAME                       2093 non-null object
# NAICS_CODE                     2093 non-null int64
# TOTAL_WORKERS                  2093 non-null int64
# NEW_EMPLOYMENT                 2093 non-null int64
# CONTINUED_EMPLOYMENT           2093 non-null int64
# CHANGE_PREVIOUS_EMPLOYMENT     2093 non-null int64
# NEW_CONCURRENT_EMPLOYMENT      2093 non-null int64
# CHANGE_EMPLOYER                2093 non-null int64
# AMENDED_PETITION               2093 non-null int64
# FULL_TIME_POSITION             2093 non-null object
# PREVAILING_WAGE                2093 non-null float64
# PW_UNIT_OF_PAY                 2092 non-null object
# PW_WAGE_LEVEL                  1670 non-null object
# PW_SOURCE                      2092 non-null object
# PW_SOURCE_YEAR                 2092 non-null float64
# PW_SOURCE_OTHER                2046 non-null object
# WAGE_RATE_OF_PAY_FROM          2093 non-null float64
# WAGE_RATE_OF_PAY_TO            2093 non-null float64
# WAGE_UNIT_OF_PAY               2093 non-null object
# H1B_DEPENDENT                  2037 non-null object
# WILLFUL_VIOLATOR               2037 non-null object
# SUPPORT_H1B                    733 non-null object
# LABOR_CON_AGREE                861 non-null object
# PUBLIC_DISCLOSURE_LOCATION     0 non-null float64
# WORKSITE_CITY                  2093 non-null object
# WORKSITE_COUNTY                2091 non-null object
# WORKSITE_STATE                 2093 non-null object
# WORKSITE_POSTAL_CODE           2093 non-null object
# ORIGINAL_CERT_DATE             115 non-null object
# dtypes: float64(6), int64(9), object(36)
# memory usage: 834.0+ KB

# %% [markdown]
# ## Printing the difference between train and test column

# %%
print("Variables not in test but in train : ", set(train.columns).difference(set(test.columns)))
# Out:
# Variables not in test but in train :  {'CASE_STATUS'}

# %% [markdown]
# ###### As we can see above output there is only one column CASE_STATUS which is in train file but not in test and it is obvious that CASE_STATUS is the target variable which we are trying to PREDICT

# %% [markdown]
# #  EDA
# #### Exploratory Data Analysis

# %%
import missingno as msno

# %%
msno.bar(train)

# %% [markdown]
# # The screenshot for number of applicants applied and got approval  for H1b through 2007 -2017
#
# # Reference: https://www.uscis.gov/sites/default/files/USCIS/Resources/Reports%20and%20Studies/Immigration%20Forms%20Data/BAHA/h-1b-2007-2017-trend-tables.pdf

# %% [markdown]
# # ![title](USimmigration.png)

# %% [markdown]
# # Cleansing and Research to understand feature variables begins..

# %%
# %%time
const_cols = [c for c in train.columns if train[c].nunique(dropna=False)==1 ]
# Out:
# CPU times: user 26.3 ms, sys: 2.64 ms, total: 28.9 ms
# Wall time: 28.3 ms

# %%
const_cols
# Out:
# ['PUBLIC_DISCLOSURE_LOCATION']

# %% [markdown]
# #### This confirms that their is only one column with constant value in this case it was complete missing value
# #### for the column 'PUBLIC_DISCLOSURE_LOCATION' which we will remove from our dataset

# %%
train.drop('PUBLIC_DISCLOSURE_LOCATION', axis=1, inplace=True)

# %%
# Originally we have 52 columns 
len(train.columns)
columns=train.columns

# %%
percent=train.isnull().sum()*100/len(train)
missing_values_in_percent = pd.DataFrame({'column_name': columns,
                                 'percent_missing': percent})

# %%
percent.sort_values(ascending=False)
# Out:
# EMPLOYER_PROVINCE              99.044327
# EMPLOYER_PHONE_EXT             95.790972
# ORIGINAL_CERT_DATE             95.343636
# EMPLOYER_BUSINESS_DBA          92.374949
# SUPPORT_H1B                    66.307442
# LABOR_CON_AGREE                57.706385
# AGENT_ATTORNEY_STATE           47.112647
# AGENT_ATTORNEY_CITY            45.445303
# PW_WAGE_LEVEL                  22.102481
# AGENT_REPRESENTING_EMPLOYER    16.958113
# EMPLOYER_PHONE                 16.958113
# EMPLOYER_COUNTRY               16.958113
# H1B_DEPENDENT                   3.029687
# WILLFUL_VIOLATOR                3.029687
# PW_SOURCE_OTHER                 2.826352
# WORKSITE_COUNTY                 0.162668
# PW_UNIT_OF_PAY                  0.061000
# PW_SOURCE_YEAR                  0.061000
# PW_SOURCE                       0.040667
# WAGE_UNIT_OF_PAY                0.020333
# WORKSITE_STATE                  0.020333
# VISA_CLASS                      0.000000
# EMPLOYMENT_START_DATE           0.000000
# EMPLOYMENT_END_DATE             0.000000
# EMPLOYER_ADDRESS                0.000000
# EMPLOYER_CITY                   0.000000
# EMPLOYER_STATE                  0.000000
# EMPLOYER_POSTAL_CODE            0.000000
# CASE_STATUS                     0.000000
# DECISION_DATE                   0.000000
# CASE_SUBMITTED                  0.000000
# EMPLOYER_NAME                   0.000000
# TOTAL_WORKERS                   0.000000
# AGENT_ATTORNEY_NAME             0.000000
# JOB_TITLE                       0.000000
# WORKSITE_CITY                   0.000000
# WAGE_RATE_OF_PAY_TO             0.000000
# WAGE_RATE_OF_PAY_FROM           0.000000
# PREVAILING_WAGE                 0.000000
# FULL_TIME_POSITION              0.000000
# AMENDED_PETITION                0.000000
# CHANGE_EMPLOYER                 0.000000
# NEW_CONCURRENT_EMPLOYMENT       0.000000
# CHANGE_PREVIOUS_EMPLOYMENT      0.000000
# CONTINUED_EMPLOYMENT            0.000000
# NEW_EMPLOYMENT                  0.000000
# WORKSITE_POSTAL_CODE            0.000000
# NAICS_CODE                      0.000000
# SOC_NAME                        0.000000
# SOC_CODE                        0.000000
# Ob                              0.000000
# dtype: float64

# %% [markdown]
# ### Above we can see the features with missing values in percentage

# %%
correlation=train.corr()

# %%
correlation
# Out:
#                                   Ob  NAICS_CODE  TOTAL_WORKERS  \
# Ob                          1.000000    0.064186       0.022781
# NAICS_CODE                  0.064186    1.000000      -0.068389
# TOTAL_WORKERS               0.022781   -0.068389       1.000000
# NEW_EMPLOYMENT              0.002137   -0.024017       0.725277
# CONTINUED_EMPLOYMENT        0.028662   -0.030026       0.506832
# CHANGE_PREVIOUS_EMPLOYMENT -0.002243   -0.027548       0.338436
# NEW_CONCURRENT_EMPLOYMENT   0.013417   -0.036485       0.081172
# CHANGE_EMPLOYER             0.022064   -0.028134       0.450929
# AMENDED_PETITION            0.042443   -0.083618       0.465268
# PREVAILING_WAGE             0.056866   -0.005413       0.031872
# PW_SOURCE_YEAR              0.070740   -0.014956       0.002924
# WAGE_RATE_OF_PAY_FROM       0.039226    0.019242      -0.003021
# WAGE_RATE_OF_PAY_TO        -0.032139   -0.078954       0.078815
#
#                             NEW_EMPLOYMENT  CONTINUED_EMPLOYMENT  \
# Ob                                0.002137              0.028662
# NAICS_CODE                       -0.024017             -0.030026
# TOTAL_WORKERS                     0.725277              0.506832
# NEW_EMPLOYMENT                    1.000000              0.084480
# CONTINUED_EMPLOYMENT              0.084480              1.000000
# CHANGE_PREVIOUS_EMPLOYMENT        0.032190              0.120104
# NEW_CONCURRENT_EMPLOYMENT         0.007098              0.080745
# CHANGE_EMPLOYER                   0.061652              0.309878
# AMENDED_PETITION                  0.036847              0.216302
# PREVAILING_WAGE                  -0.030373              0.062989
# PW_SOURCE_YEAR                   -0.018418             -0.005170
# WAGE_RATE_OF_PAY_FROM            -0.046057              0.039932
# WAGE_RATE_OF_PAY_TO               0.018932              0.022644
#
#                             CHANGE_PREVIOUS_EMPLOYMENT  \
# Ob                                           -0.002243
# NAICS_CODE                                   -0.027548
# TOTAL_WORKERS                                 0.338436
# NEW_EMPLOYMENT                                0.032190
# CONTINUED_EMPLOYMENT                          0.120104
# CHANGE_PREVIOUS_EMPLOYMENT                    1.000000
# NEW_CONCURRENT_EMPLOYMENT                     0.062316
# CHANGE_EMPLOYER                               0.158567
# AMENDED_PETITION                              0.072110
# PREVAILING_WAGE                               0.024007
# PW_SOURCE_YEAR                                0.023756
# WAGE_RATE_OF_PAY_FROM                         0.010309
# WAGE_RATE_OF_PAY_TO                           0.044174
#
#                             NEW_CONCURRENT_EMPLOYMENT  CHANGE_EMPLOYER  \
# Ob                                           0.013417         0.022064
# NAICS_CODE                                  -0.036485        -0.028134
# TOTAL_WORKERS                                0.081172         0.450929
# NEW_EMPLOYMENT                               0.007098         0.061652
# CONTINUED_EMPLOYMENT                         0.080745         0.309878
# CHANGE_PREVIOUS_EMPLOYMENT                   0.062316         0.158567
# NEW_CONCURRENT_EMPLOYMENT                    1.000000         0.026513
# CHANGE_EMPLOYER                              0.026513         1.000000
# AMENDED_PETITION                             0.015665         0.270353
# PREVAILING_WAGE                             -0.105212         0.072651
# PW_SOURCE_YEAR                               0.007997        -0.007481
# WAGE_RATE_OF_PAY_FROM                       -0.085437         0.051604
# WAGE_RATE_OF_PAY_TO                         -0.007206         0.060467
#
#                             AMENDED_PETITION  PREVAILING_WAGE  PW_SOURCE_YEAR  \
# Ob                                  0.042443         0.056866        0.070740
# NAICS_CODE                         -0.083618        -0.005413       -0.014956
# TOTAL_WORKERS                       0.465268         0.031872        0.002924
# NEW_EMPLOYMENT                      0.036847        -0.030373       -0.018418
# CONTINUED_EMPLOYMENT                0.216302         0.062989       -0.005170
# CHANGE_PREVIOUS_EMPLOYMENT          0.072110         0.024007        0.023756
# NEW_CONCURRENT_EMPLOYMENT           0.015665        -0.105212        0.007997
# CHANGE_EMPLOYER                     0.270353         0.072651       -0.007481
# AMENDED_PETITION                    1.000000         0.043543        0.025233
# PREVAILING_WAGE                     0.043543         1.000000        0.032324
# PW_SOURCE_YEAR                      0.025233         0.032324        1.000000
# WAGE_RATE_OF_PAY_FROM               0.027353         0.804167        0.017708
# WAGE_RATE_OF_PAY_TO                 0.077515         0.286451       -0.063845
#
#                             WAGE_RATE_OF_PAY_FROM  WAGE_RATE_OF_PAY_TO
# Ob                                       0.039226            -0.032139
# NAICS_CODE                               0.019242            -0.078954
# TOTAL_WORKERS                           -0.003021             0.078815
# NEW_EMPLOYMENT                          -0.046057             0.018932
# CONTINUED_EMPLOYMENT                     0.039932             0.022644
# CHANGE_PREVIOUS_EMPLOYMENT               0.010309             0.044174
# NEW_CONCURRENT_EMPLOYMENT               -0.085437            -0.007206
# CHANGE_EMPLOYER                          0.051604             0.060467
# AMENDED_PETITION                         0.027353             0.077515
# PREVAILING_WAGE                          0.804167             0.286451
# PW_SOURCE_YEAR                           0.017708            -0.063845
# WAGE_RATE_OF_PAY_FROM                    1.000000             0.188030
# WAGE_RATE_OF_PAY_TO                      0.188030             1.000000

# %%
len(train['EMPLOYER_CITY'].unique())
# Out:
# 874

# %%
sns.heatmap(correlation,
           xticklabels=correlation.columns,
        yticklabels=correlation.columns)

# %% [markdown]
# ## Correlation in the dataset without transformation

# %%
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

correlation.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8 th {
#           font-size: 7pt;
#     }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8 td {
#           padding: 0em 0em;
#     }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8 th:hover {
#           font-size: 12pt;
#     }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col0 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col1 {
#             background-color:  #de5c76;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col2 {
#             background-color:  #db4e6a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col3 {
#             background-color:  #d94764;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col4 {
#             background-color:  #dc516d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col5 {
#             background-color:  #d94563;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col6 {
#             background-color:  #da4b68;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col7 {
#             background-color:  #db4e6a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col8 {
#             background-color:  #dc5570;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col9 {
#             background-color:  #de5b75;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col10 {
#             background-color:  #de5f79;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col11 {
#             background-color:  #dc546f;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row0_col12 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col0 {
#             background-color:  #e16c84;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col1 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col2 {
#             background-color:  #d8405e;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col3 {
#             background-color:  #db4f6b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col4 {
#             background-color:  #db4d69;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col5 {
#             background-color:  #db4e6a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col6 {
#             background-color:  #da4b68;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col7 {
#             background-color:  #db4e6a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col8 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col9 {
#             background-color:  #dc5570;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col10 {
#             background-color:  #dc526e;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col11 {
#             background-color:  #de5e77;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row1_col12 {
#             background-color:  #d73d5c;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col0 {
#             background-color:  #dd5a74;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col1 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col2 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col3 {
#             background-color:  #9eb9db;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col4 {
#             background-color:  #e7eef6;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col5 {
#             background-color:  #f3c6cf;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col6 {
#             background-color:  #e16d85;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col7 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col8 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col9 {
#             background-color:  #de5e77;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col10 {
#             background-color:  #dc546f;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col11 {
#             background-color:  #dc516d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row2_col12 {
#             background-color:  #e16d85;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row3_col0 {
#             background-color:  #da4b68;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row3_col1 {
#             background-color:  #d94261;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row3_col2 {
#             background-color:  #a0bbdc;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row3_col3 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row3_col4 {
#             background-color:  #e06880;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row3_col5 {
#             background-color:  #dd5671;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row3_col6 {
#             background-color:  #db4e6a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_c5a4c50a_0b89_11e9_986e_d4619d373cf8row3_

# %% [markdown]
# ### How many applicants were approved VS denied for the visa

# %%
target=train['CASE_STATUS'].value_counts()
print("Visa Declined ",(2068/(2068+2850)),"%")
# Out:
# Visa Declined  0.42049613664091096 %

# %% [markdown]
# #### This shows 42.0 percent visa were declined

# %%
target.plot.pie()
# Same information visually

# %%
plt.figure(figsize=(10,8))
ax=train['CASE_STATUS'].value_counts().sort_values(ascending=True).plot.barh(width=0.9,color='#ffd700')
for i, v in enumerate(train['CASE_STATUS'].value_counts().sort_values(ascending=True).values): 
    ax.text(.8, i, v,fontsize=12,color='b',weight='bold')
plt.title('Case Status in Bar Chart')
plt.show()

# %% [markdown]
# # Further Exploration

# %% [markdown]
# ##### Before moving ahead and removing any information we would like to understand the features

# %%
plt.figure(figsize=(10,8))
ax=train['WORKSITE_STATE'].value_counts().sort_values(ascending=False)[:10].plot.barh(width=0.9,color='#ffd700')
for i, v in enumerate(train['WORKSITE_STATE'].value_counts().sort_values(ascending=False).values[:10]): 
    ax.text(.9, i, v,fontsize=18,color='r',weight='bold')
plt.title('Frequancy of Employer')
fig=plt.gca()
fig.invert_yaxis()
plt.show()

# %%
employer=train['EMPLOYER_BUSINESS_DBA'].value_counts()
employer
# Out:
# MASTECH DIGITAL TECHNOLOGIES, INC.                 6
# INSTITUTION OF HIGHER EDUCATION                    6
# MEDPRO                                             4
# BLOOMBERG                                          4
# 2 TOWER CENTER BLVD                                4
# UNIVERSITY OF PENNSYLVANIA                         4
# CREDIT SUISSE                                      3
# CA TECHNOLOGIES                                    3
# CNSI                                               3
# ETA                                                3
# VEDICSOFT                                          3
# --                                                 2
# COMPWORLDWIDE                                      2
# NYU SCHOOL OF MEDICINE                             2
# NONE                                               2
# GABLES ESTATES TAX & ADVISORY SERVICES, P.A.       2
# INTERNATIONAL TECHNOLOGICAL UNIVERSITY             2
# SELECT REHABILITATION                              2
# WWW.MOVERS.COM                                     2
# CITRIX SYSTEMS, INC.                               2
# CAPRUS IT                                          2
# AMERICAN EAGLE                                     2
# BROADCOM LIMITED                                   2
# INDIRECT WHOLLY-OWNED SUBSIDIARY OF PEARSON PLC    2
# SAGITEC SOLUTIONS                                  2
# CVS PHARMACY                                       2
# PATRICIA A. WILLIAMS                               2
# STACK LIGHTING                                     2
# SOFTVISION, LLC                                    2
# SIGNATURE IT SOLUTIONS LLC                         2
#                                                   ..
# THE INTERNATIONAL SCHOOL OF MINNESOTA              1
# AIRFOX                                             1
# SEMPER SOLARIS                                     1
# SMARTWORKS, LLC                                    1
# INSIGHT & INNOVATION INSTITUTE                     1
# MASSACHUSETTS GENERAL HOSPITAL                     1
# VNA OF MARYLAND                                    1
# BNP PARIBAS                                        1
# COLLEGIATE PRESS                                   1
# DOUBLETREE BY HILTON                               1
# P&C CONSTRUCTION                                   1
# KOSTA BROWNE WINERY                                1
# AG ENGINEERING GROUP, INC.                         1
# FOUR SEAS                                          1
# SYNCHROTRON CORP                                   1
# DBA ALLIANCE MEDICAL GROUP                         1
# THE GLIMMERGLASS FESTIVAL                          1
# THE UNIVERSITY OF TENNESSEE AT CHATTANOOGA         1
# ELASTIC                                            1
# CHEMTEX                                            1
# RLS                                                1
# INTERNATIONAL STUDENTS & SCHOLARS OFFICE           1
# NOKIA                                              1
# NEW YORK CITY DEPARTMENT OF EDUCATION              1
# VALCOMELTON                                        1
# OFFICE OF INTERNATIONAL STUDENTS AND SCHOLARS      1
# ARATHI                                             1
# JEFFERSON DENTAL CLINICS                           1
# INFOWAYS                                           1
# INSPIRED TECHNOLOGY CONCEPTS, INC                  1
# Name: EMPLOYER_BUSINESS_DBA, Length: 310, dtype: int64

# %%
employers=employer[:10]

# %%
employers.plot.barh()

# %%
plt.figure(figsize=(10,8))
ax=train['EMPLOYER_NAME'].value_counts().sort_values(ascending=False)[:10].plot.barh(width=0.9,color='#ffd700')
for i, v in enumerate(train['EMPLOYER_NAME'].value_counts().sort_values(ascending=False).values[:10]): 
    ax.text(.9, i, v,fontsize=18,color='r',weight='bold')
plt.title('Frequancy of Employer')
fig=plt.gca()
fig.invert_yaxis()
plt.show()

# %% [markdown]
# # Let us find the Acceptance rate of the Employers

# %%
emp_rate1=train[train['CASE_STATUS']=='CERTIFIED']
emp_rate1=emp_rate1.groupby(['EMPLOYER_NAME','CASE_STATUS'])['CASE_SUBMITTED'].count().reset_index()
emp_rate2=train[train['CASE_STATUS']=='DENIED']
emp_rate2=emp_rate2.groupby(['EMPLOYER_NAME','CASE_STATUS'])['CASE_SUBMITTED'].count().reset_index()
aa1=emp_rate2.sort_values('CASE_SUBMITTED',ascending=False)[:100]
aa2=emp_rate1.sort_values('CASE_SUBMITTED',ascending=False)[:100]
aa3=aa2.merge(aa1,left_on='EMPLOYER_NAME',right_on='EMPLOYER_NAME',how='left').dropna()
aa3['Acceptance_rate']=aa3['CASE_SUBMITTED_x']/(aa3['CASE_SUBMITTED_x']+aa3['CASE_SUBMITTED_y'])
aa3.sort_values('Acceptance_rate',ascending=False)[['EMPLOYER_NAME','Acceptance_rate']][:15]
# Out:
#                                       EMPLOYER_NAME  Acceptance_rate
# 7                             MICROSOFT CORPORATION         0.914286
# 1                 TATA CONSULTANCY SERVICES LIMITED         0.887097
# 6                            ERNST & YOUNG U.S. LLP         0.868421
# 15  COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION         0.812500
# 2                             CAPGEMINI AMERICA INC         0.803571
# 5                           DELOITTE CONSULTING LLP         0.785714
# 9                                     WIPRO LIMITED         0.774194
# 34                                     TECHLAND INC         0.750000
# 43                                   SOGETI USA LLC         0.714286
# 44                             BANK OF AMERICA N.A.         0.714286
# 14                 LARSEN & TOUBRO INFOTECH LIMITED         0.650000
# 12                                      GOOGLE INC.         0.625000
# 11                             AMAZON CORPORATE LLC         0.617647
# 88                THE PENNSYLVANIA STATE UNIVERSITY         0.600000
# 65                          MICRON TECHNOLOGY, INC.         0.600000

# %%
data_peeps=train.dropna(subset=['JOB_TITLE'])
data_peeps=data_peeps[data_peeps['JOB_TITLE'].str.contains('DATA')]
data_scientists=data_peeps[data_peeps['JOB_TITLE'].str.contains('DATA SCIENTIST')]
data_analyst=data_peeps[data_peeps['JOB_TITLE'].str.contains('DATA ANALYST')]
data_eng=data_peeps[data_peeps['JOB_TITLE'].str.contains('DATA ENG')]

# %% [markdown]
# ## Let's prepare dataset for Machine Learning
# #### In this section we will focus on handling missing values, converting categorical values to numerical. We need to handle missing values and before feeding the data into machine learning algorithm because the mathematics under most machine learning models assume the data is numeric and contains no missing values

# %% [markdown]
# #### I have replaced the all missing values in column EMPLOYER_BUSINESS_DBA

# %% [raw]
# We are going get rid of redundant columns as in country we only have all United states of America and the missing values in that column were also USA Reason for removing Employer Province aswe have another column which is called EMPLOYER STATE which is same as province'EMPLOYER_COUNTRY''EMPLOYER_PROVINCE'

# %%
#train[train['EMPLOYER_COUNTRY']==train['EMPLOYER_COUNTRY'].idxmax()]

# %% [markdown]
# # Tidy Data

# %%
train.head()
# Out:
#    Ob CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS  \
# 0   1      DENIED      5/25/2017     5/25/2017       H-1B
# 1   2      DENIED      11/4/2014     8/16/2017       H-1B
# 2   3      DENIED      10/6/2016    10/13/2016       H-1B
# 3   4      DENIED      8/14/2017     8/14/2017       H-1B
# 4   5      DENIED      4/20/2017     4/20/2017       H-1B
#
#   EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE                   EMPLOYER_NAME  \
# 0             9/21/2017           9/20/2020                 VERTISYSTEM INC
# 1             12/8/2014           12/7/2017                     GOOGLE INC.
# 2            11/11/2016          11/10/2019  KIMBERLY-CLARK WORLDWIDE, INC.
# 3             8/14/2017           8/14/2020                    EMBTEL, INC.
# 4            10/16/2017          10/15/2020        SPACE TIME INSIGHT, INC.
#
#   EMPLOYER_BUSINESS_DBA           EMPLOYER_ADDRESS        ...          \
# 0                   NaN   39300 CIVIC CENTER DRIVE        ...
# 1                   NaN  1600 AMPHITHEATRE PARKWAY        ...
# 2                   NaN         2001 MARATHON AVE.        ...
# 3                   NaN  39159 PASEO PADRE PARKWAY        ...
# 4                   NaN           1850 GATEWAY DR.        ...
#
#   WAGE_UNIT_OF_PAY H1B_DEPENDENT WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE  \
# 0             Year             Y                N           Y               Y
# 1             Year             N                N         NaN             NaN
# 2             Year             N                N         NaN             NaN
# 3             Year             Y                N           Y               Y
# 4             Year             N                N         NaN             NaN
#
#    WORKSITE_CITY WORKSITE_COUNTY WORKSITE_STATE WORKSITE_POSTAL_CODE  \
# 0      SUNNYVALE     SANTA CLARA             CA                94085
# 1  MOUNTAIN VIEW     SANTA CLARA             CA                94043
# 2         NEENAH       WINNEBAGO             WI                54956
# 3      CHARLOTTE     MECKLENBURG             NC                28202
# 4        MEMPHIS          SHELBY             TN                38125
#
#   ORIGINAL_CERT_DATE
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 51 columns]

# %% [markdown]
# ## Cleansing 1.1
# #### Date Transformation: All the dates are in string format which we would like to convert into date
# #### * We would like to see the difference of date that is employment starting date and employment end date.
# #### * We would like to see the processing time of decision making
# #### We will add a new column for each employment duration and processing time

# %%
# Here we have transformed all the string formated dates to date format
# %timeit
from datetime import datetime
train['EMPLOYMENT_START_DATE']=pd.to_datetime(train['EMPLOYMENT_START_DATE'])
train['EMPLOYMENT_END_DATE']=pd.to_datetime(train['EMPLOYMENT_END_DATE'])
train['CASE_SUBMITTED']=pd.to_datetime(train['CASE_SUBMITTED'])
train['DECISION_DATE']=pd.to_datetime(train['DECISION_DATE'])

# %%
# Verification of date format transformation

train.describe()
# Out:
#                 Ob     NAICS_CODE  TOTAL_WORKERS  NEW_EMPLOYMENT  \
# count  4918.000000    4918.000000    4918.000000     4918.000000
# mean   2459.500000  438568.020130       1.699268        0.766165
# std    1419.848642  204422.510048       3.857599        2.605320
# min       1.000000    2122.000000       1.000000        0.000000
# 25%    1230.250000  424240.000000       1.000000        0.000000
# 50%    2459.500000  541511.000000       1.000000        0.000000
# 75%    3688.750000  541511.000000       1.000000        1.000000
# max    4918.000000  926130.000000      75.000000       75.000000
#
#        CONTINUED_EMPLOYMENT  CHANGE_PREVIOUS_EMPLOYMENT  \
# count           4918.000000                 4918.000000
# mean               0.296869                    0.110411
# std                1.166491                    0.943281
# min                0.000000                    0.000000
# 25%                0.000000                    0.000000
# 50%                0.000000                    0.000000
# 75%                0.000000                    0.000000
# max               50.000000                   50.000000
#
#        NEW_CONCURRENT_EMPLOYMENT  CHANGE_EMPLOYER  AMENDED_PETITION  \
# count                4918.000000      4918.000000       4918.000000
# mean                    0.008337         0.231802          0.269622
# std                     0.105433         0.836398          1.224660
# min                     0.000000         0.000000          0.000000
# 25%                     0.000000         0.000000          0.000000
# 50%                     0.000000         0.000000          0.000000
# 75%                     0.000000         0.000000          0.000000
# max                     2.000000        15.000000         15.000000
#
#        PREVAILING_WAGE  PW_SOURCE_YEAR  WAGE_RATE_OF_PAY_FROM  \
# count      4918.000000     4915.000000            4918.000000
# mean      71229.232574     2016.120041           82009.587885
# std       34648.534323        0.742782           48850.029727
# min           0.000000     2001.000000               0.000000
# 25%       55895.000000     2016.000000           61922.000000
# 50%       69628.000000     2016.000000           75795.000000
# 75%       88067.000000     2017.000000          100000.000000
# max      336000.000000     2017.000000          850000.000000
#
#        WAGE_RATE_OF_PAY_TO
# count          4918.000000
# mean          25095.936682
# std           53984.001841
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max          804391.000000

# %%
train.head()
# Out:
#    Ob CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS  \
# 0   1      DENIED     2017-05-25    2017-05-25       H-1B
# 1   2      DENIED     2014-11-04    2017-08-16       H-1B
# 2   3      DENIED     2016-10-06    2016-10-13       H-1B
# 3   4      DENIED     2017-08-14    2017-08-14       H-1B
# 4   5      DENIED     2017-04-20    2017-04-20       H-1B
#
#   EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE                   EMPLOYER_NAME  \
# 0            2017-09-21          2020-09-20                 VERTISYSTEM INC
# 1            2014-12-08          2017-12-07                     GOOGLE INC.
# 2            2016-11-11          2019-11-10  KIMBERLY-CLARK WORLDWIDE, INC.
# 3            2017-08-14          2020-08-14                    EMBTEL, INC.
# 4            2017-10-16          2020-10-15        SPACE TIME INSIGHT, INC.
#
#   EMPLOYER_BUSINESS_DBA           EMPLOYER_ADDRESS        ...          \
# 0                   NaN   39300 CIVIC CENTER DRIVE        ...
# 1                   NaN  1600 AMPHITHEATRE PARKWAY        ...
# 2                   NaN         2001 MARATHON AVE.        ...
# 3                   NaN  39159 PASEO PADRE PARKWAY        ...
# 4                   NaN           1850 GATEWAY DR.        ...
#
#   WAGE_UNIT_OF_PAY H1B_DEPENDENT WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE  \
# 0             Year             Y                N           Y               Y
# 1             Year             N                N         NaN             NaN
# 2             Year             N                N         NaN             NaN
# 3             Year             Y                N           Y               Y
# 4             Year             N                N         NaN             NaN
#
#    WORKSITE_CITY WORKSITE_COUNTY WORKSITE_STATE WORKSITE_POSTAL_CODE  \
# 0      SUNNYVALE     SANTA CLARA             CA                94085
# 1  MOUNTAIN VIEW     SANTA CLARA             CA                94043
# 2         NEENAH       WINNEBAGO             WI                54956
# 3      CHARLOTTE     MECKLENBURG             NC                28202
# 4        MEMPHIS          SHELBY             TN                38125
#
#   ORIGINAL_CERT_DATE
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 51 columns]

# %%
# We will add a column each to see the difference between the date
start_employment=train['EMPLOYMENT_START_DATE']
end_employment=train['EMPLOYMENT_END_DATE']
case_submission_date=train['CASE_SUBMITTED']
Decision_date=train['DECISION_DATE']

train['Employment_duration']= end_employment - start_employment
train['Processing_time']  = Decision_date - case_submission_date

# %%
train.head()
# Out:
#    Ob CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS  \
# 0   1      DENIED     2017-05-25    2017-05-25       H-1B
# 1   2      DENIED     2014-11-04    2017-08-16       H-1B
# 2   3      DENIED     2016-10-06    2016-10-13       H-1B
# 3   4      DENIED     2017-08-14    2017-08-14       H-1B
# 4   5      DENIED     2017-04-20    2017-04-20       H-1B
#
#   EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE                   EMPLOYER_NAME  \
# 0            2017-09-21          2020-09-20                 VERTISYSTEM INC
# 1            2014-12-08          2017-12-07                     GOOGLE INC.
# 2            2016-11-11          2019-11-10  KIMBERLY-CLARK WORLDWIDE, INC.
# 3            2017-08-14          2020-08-14                    EMBTEL, INC.
# 4            2017-10-16          2020-10-15        SPACE TIME INSIGHT, INC.
#
#   EMPLOYER_BUSINESS_DBA           EMPLOYER_ADDRESS       ...        \
# 0                   NaN   39300 CIVIC CENTER DRIVE       ...
# 1                   NaN  1600 AMPHITHEATRE PARKWAY       ...
# 2                   NaN         2001 MARATHON AVE.       ...
# 3                   NaN  39159 PASEO PADRE PARKWAY       ...
# 4                   NaN           1850 GATEWAY DR.       ...
#
#   WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE  WORKSITE_CITY WORKSITE_COUNTY  \
# 0                N           Y               Y      SUNNYVALE     SANTA CLARA
# 1                N         NaN             NaN  MOUNTAIN VIEW     SANTA CLARA
# 2                N         NaN             NaN         NEENAH       WINNEBAGO
# 3                N           Y               Y      CHARLOTTE     MECKLENBURG
# 4                N         NaN             NaN        MEMPHIS          SHELBY
#
#   WORKSITE_STATE WORKSITE_POSTAL_CODE ORIGINAL_CERT_DATE Employment_duration  \
# 0             CA                94085                NaN           1095 days
# 1             CA                94043                NaN           1095 days
# 2             WI                54956                NaN           1094 days
# 3             NC                28202                NaN           1096 days
# 4             TN                38125                NaN           1095 days
#
#   Processing_time
# 0          0 days
# 1       1016 days
# 2          7 days
# 3          0 days
# 4          0 days
#
# [5 rows x 53 columns]

# %%
summary=train.describe()
summary
# Out:
#                 Ob     NAICS_CODE  TOTAL_WORKERS  NEW_EMPLOYMENT  \
# count  4918.000000    4918.000000    4918.000000     4918.000000
# mean   2459.500000  438568.020130       1.699268        0.766165
# std    1419.848642  204422.510048       3.857599        2.605320
# min       1.000000    2122.000000       1.000000        0.000000
# 25%    1230.250000  424240.000000       1.000000        0.000000
# 50%    2459.500000  541511.000000       1.000000        0.000000
# 75%    3688.750000  541511.000000       1.000000        1.000000
# max    4918.000000  926130.000000      75.000000       75.000000
#
#        CONTINUED_EMPLOYMENT  CHANGE_PREVIOUS_EMPLOYMENT  \
# count           4918.000000                 4918.000000
# mean               0.296869                    0.110411
# std                1.166491                    0.943281
# min                0.000000                    0.000000
# 25%                0.000000                    0.000000
# 50%                0.000000                    0.000000
# 75%                0.000000                    0.000000
# max               50.000000                   50.000000
#
#        NEW_CONCURRENT_EMPLOYMENT  CHANGE_EMPLOYER  AMENDED_PETITION  \
# count                4918.000000      4918.000000       4918.000000
# mean                    0.008337         0.231802          0.269622
# std                     0.105433         0.836398          1.224660
# min                     0.000000         0.000000          0.000000
# 25%                     0.000000         0.000000          0.000000
# 50%                     0.000000         0.000000          0.000000
# 75%                     0.000000         0.000000          0.000000
# max                     2.000000        15.000000         15.000000
#
#        PREVAILING_WAGE  PW_SOURCE_YEAR  WAGE_RATE_OF_PAY_FROM  \
# count      4918.000000     4915.000000            4918.000000
# mean      71229.232574     2016.120041           82009.587885
# std       34648.534323        0.742782           48850.029727
# min           0.000000     2001.000000               0.000000
# 25%       55895.000000     2016.000000           61922.000000
# 50%       69628.000000     2016.000000           75795.000000
# 75%       88067.000000     2017.000000          100000.000000
# max      336000.000000     2017.000000          850000.000000
#
#        WAGE_RATE_OF_PAY_TO        Employment_duration  \
# count          4918.000000                       4918
# mean          25095.936682  1035 days 18:11:16.372509
# std           53984.001841   175 days 16:46:09.951196
# min               0.000000            1 days 00:00:00
# 25%               0.000000         1094 days 00:00:00
# 50%               0.000000         1095 days 00:00:00
# 75%               0.000000         1095 days 00:00:00
# max          804391.000000         1096 days 00:00:00
#
#                 Processing_time
# count                      4918
# mean    57 days 19:46:26.010573
# std    190 days 20:01:05.694568
# min             0 days 00:00:00
# 25%             3 days 00:00:00
# 50%             6 days 00:00:00
# 75%             6 days 00:00:00
# max          1263 days 00:00:00

# %%
summary[['PREVAILING_WAGE','Employment_duration','Processing_time']]
# Out:
#        PREVAILING_WAGE        Employment_duration           Processing_time
# count      4918.000000                       4918                      4918
# mean      71229.232574  1035 days 18:11:16.372509   57 days 19:46:26.010573
# std       34648.534323   175 days 16:46:09.951196  190 days 20:01:05.694568
# min           0.000000            1 days 00:00:00           0 days 00:00:00
# 25%       55895.000000         1094 days 00:00:00           3 days 00:00:00
# 50%       69628.000000         1095 days 00:00:00           6 days 00:00:00
# 75%       88067.000000         1095 days 00:00:00           6 days 00:00:00
# max      336000.000000         1096 days 00:00:00        1263 days 00:00:00

# %%
train['Processing_time'].median()
# Out:
# Timedelta('6 days 00:00:00')

# %%
train['Processing_time'].mean()
# Out:
# Timedelta('57 days 19:46:26.010573')

# %%
processingtime=train['Processing_time'].value_counts()
process=processingtime[:10]
process
# Out:
# 6 days     1933
# 4 days      643
# 0 days      563
# 7 days      359
# 1 days      310
# 2 days      210
# 5 days      204
# 3 days      156
# 8 days       25
# 26 days       4
# Name: Processing_time, dtype: int64

# %%
duration=train['Employment_duration'].value_counts()

duration
dura=duration[:10]
dura
# Out:
# 1095 days    2662
# 1096 days     896
# 1094 days     530
# 729 days      108
# 1093 days     106
# 730 days       77
# 364 days       53
# 1092 days      20
# 728 days       11
# 1065 days      10
# Name: Employment_duration, dtype: int64

# %%
dura.plot.barh()

# %% [markdown]
# #### Most of the job offered were 1095 which is 3 years

# %%
train.shape
# Out:
# (4918, 53)

# %%
print((train[1:53]==0).sum())
# Out:
# Ob                              0
# CASE_STATUS                     0
# CASE_SUBMITTED                  0
# DECISION_DATE                   0
# VISA_CLASS                      0
# EMPLOYMENT_START_DATE           0
# EMPLOYMENT_END_DATE             0
# EMPLOYER_NAME                   0
# EMPLOYER_BUSINESS_DBA           0
# EMPLOYER_ADDRESS                0
# EMPLOYER_CITY                   0
# EMPLOYER_STATE                  0
# EMPLOYER_POSTAL_CODE            0
# EMPLOYER_COUNTRY                0
# EMPLOYER_PROVINCE               0
# EMPLOYER_PHONE                  0
# EMPLOYER_PHONE_EXT              0
# AGENT_REPRESENTING_EMPLOYER     0
# AGENT_ATTORNEY_NAME             0
# AGENT_ATTORNEY_CITY             0
# AGENT_ATTORNEY_STATE            0
# JOB_TITLE                       0
# SOC_CODE                        0
# SOC_NAME                        0
# NAICS_CODE                      0
# TOTAL_WORKERS                   0
# NEW_EMPLOYMENT                 28
# CONTINUED_EMPLOYMENT           39
# CHANGE_PREVIOUS_EMPLOYMENT     49
# NEW_CONCURRENT_EMPLOYMENT      52
# CHANGE_EMPLOYER                43
# AMENDED_PETITION               45
# FULL_TIME_POSITION              0
# PREVAILING_WAGE                 1
# PW_UNIT_OF_PAY                  0
# PW_WAGE_LEVEL                   0
# PW_SOURCE                       0
# PW_SOURCE_YEAR                  0
# PW_SOURCE_OTHER                 0
# WAGE_RATE_OF_PAY_FROM           0
# WAGE_RATE_OF_PAY_TO            33
# WAGE_UNIT_OF_PAY                0
# H1B_DEPENDENT                   0
# WILLFUL_VIOLATOR                0
# SUPPORT_H1B                     0
# LABOR_CON_AGREE                 0
# WORKSITE_CITY                   0
# WORKSITE_COUNTY                 0
# WORKSITE_STATE                  0
# WORKSITE_POSTAL_CODE            0
# ORIGINAL_CERT_DATE              0
# Employment_duration             0
# Processing_time                 0
# dtype: int64

# %% [markdown]
# # Cleansing 1.2 Imputing Missing Values and transforming the object variables in number for modeling

# %%
train.CASE_STATUS.replace(('CERTIFIED', 'DENIED'), (1, 0), inplace=True)
# Changing the CASE_STATUS column to 0 and 1 where 0 = DENIED A and 1 = CERTIFIED

# %%
# SUPPORT_H1B had 3 unique values Y,N and nan this step will replace all nan
# with 2

# %%
train['EMPLOYER_PHONE'] = (
    pd.to_numeric(train['EMPLOYER_PHONE'],
                  errors='coerce')
      .fillna(0)
    )


train['EMPLOYER_PHONE_EXT'] = (
    pd.to_numeric(train['EMPLOYER_PHONE_EXT'],
                  errors='coerce')
      .fillna(0)
    )
train.drop('EMPLOYER_COUNTRY',axis=1,inplace=True)

 #Replacing NaN value in column with EMPLOYER_PHONE_EXT with 0
train['EMPLOYER_PHONE_EXT'].replace(0, np.nan, inplace= True)
#Replacing NaN value in column with EMPLOYER_PHONE with 0
train['EMPLOYER_PHONE'].replace(0, np.nan, inplace= True)

train['SUPPORT_H1B'].fillna(value=0,inplace=True)
train['EMPLOYER_PHONE'].isna().sum()
# we had 834 missing values i.e employer did not provide phone number which we are converting to 0
train['EMPLOYER_PHONE'].fillna(value=0,inplace=True)
#E_3 = train.loc[train['VISA_CLASS'] == 'E-3 Australian', ['CASE_STATUS']]
#E_3

train['AGENT_ATTORNEY_CITY'].fillna(value=0,inplace=True)
train['AGENT_ATTORNEY_STATE'].fillna(value=0,inplace=True)

train['EMPLOYER_PROVINCE'].fillna(value=0,inplace=True)
train['EMPLOYER_PHONE_EXT'].fillna(value=0,inplace=True)
train['EMPLOYER_BUSINESS_DBA'].fillna(value=0,inplace=True)
train['PW_WAGE_LEVEL'].fillna(value=0,inplace=True)
# We are replacing missing values with 0 for this column 
train['AGENT_REPRESENTING_EMPLOYER'].fillna(value=0,inplace=True)
# this step will replace all the column rows with Y and N to 1 and 0
train['SUPPORT_H1B']=pd.Series(np.where(train.SUPPORT_H1B.values=='Y',0,1),train.index)
train['EMPLOYER_PROVINCE'].fillna(value=0,inplace=True)
train['LABOR_CON_AGREE'].fillna(value=0,inplace=True)
train['ORIGINAL_CERT_DATE'].fillna(value=0,inplace=True)
train['PW_SOURCE_OTHER'].fillna(value=0,inplace=True)
train['H1B_DEPENDENT'].fillna(value=0,inplace=True)
train['WILLFUL_VIOLATOR'].fillna(value=0,inplace=True)

#COLUMNS TO BE DROPPED
train.drop('PUBLIC_DISCLOSURE_LOCATION', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1764-1ca7048d90ea> in <module>()
#      11       .fillna(0)
#      12     )
# ---> 13 train.drop('EMPLOYER_COUNTRY',axis=1,inplace=True)
#      14
#      15  #Replacing NaN value in column with EMPLOYER_PHONE_EXT with 0
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['EMPLOYER_COUNTRY'] not found in axis"

# %%
trainwithoutduration.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4918 entries, 0 to 4917
# Data columns (total 48 columns):
# Ob                             4918 non-null int64
# CASE_STATUS                    4918 non-null int64
# CASE_SUBMITTED                 4918 non-null datetime64[ns]
# DECISION_DATE                  4918 non-null datetime64[ns]
# VISA_CLASS                     4918 non-null int64
# EMPLOYER_NAME                  4918 non-null int64
# EMPLOYER_BUSINESS_DBA          4918 non-null int64
# EMPLOYER_ADDRESS               4918 non-null int64
# EMPLOYER_CITY                  4918 non-null int64
# EMPLOYER_STATE                 4918 non-null int64
# EMPLOYER_POSTAL_CODE           4918 non-null int64
# EMPLOYER_PROVINCE              4918 non-null int64
# EMPLOYER_PHONE                 4918 non-null int64
# EMPLOYER_PHONE_EXT             4918 non-null int64
# AGENT_REPRESENTING_EMPLOYER    4918 non-null int64
# AGENT_ATTORNEY_NAME            4918 non-null int64
# AGENT_ATTORNEY_CITY            4918 non-null int64
# AGENT_ATTORNEY_STATE           4918 non-null int64
# JOB_TITLE                      4918 non-null int64
# SOC_CODE                       4918 non-null int64
# SOC_NAME                       4918 non-null int64
# NAICS_CODE                     4918 non-null int64
# TOTAL_WORKERS                  4918 non-null int64
# NEW_EMPLOYMENT                 4918 non-null int64
# CONTINUED_EMPLOYMENT           4918 non-null int64
# CHANGE_PREVIOUS_EMPLOYMENT     4918 non-null int64
# NEW_CONCURRENT_EMPLOYMENT      4918 non-null int64
# CHANGE_EMPLOYER                4918 non-null int64
# AMENDED_PETITION               4918 non-null int64
# FULL_TIME_POSITION             4918 non-null int64
# PREVAILING_WAGE                4918 non-null float64
# PW_UNIT_OF_PAY                 4918 non-null int64
# PW_WAGE_LEVEL                  4918 non-null int64
# PW_SOURCE                      4918 non-null int64
# PW_SOURCE_YEAR                 4915 non-null float64
# PW_SOURCE_OTHER                4918 non-null int64
# WAGE_RATE_OF_PAY_FROM          4918 non-null float64
# WAGE_RATE_OF_PAY_TO            4918 non-null float64
# WAGE_UNIT_OF_PAY               4918 non-null int64
# H1B_DEPENDENT                  4918 non-null int64
# WILLFUL_VIOLATOR               4918 non-null int64
# SUPPORT_H1B                    4918 non-null int64
# LABOR_CON_AGREE                4918 non-null int64
# WORKSITE_CITY                  4918 non-null int64
# WORKSITE_COUNTY                4918 non-null int64
# WORKSITE_STATE                 4918 non-null int64
# WORKSITE_POSTAL_CODE           4918 non-null int64
# ORIGINAL_CERT_DATE             4918 non-null int64
# dtypes: datetime64[ns](2), float64(4), int64(42)
# memory usage: 1.8 MB

# %%
trainwithoutduration=trainwithoutduration

# %%
test['EMPLOYER_PHONE'] = (
    pd.to_numeric(test['EMPLOYER_PHONE'],
                  errors='coerce')
      .fillna(0)
    )


test['EMPLOYER_PHONE_EXT'] = (
    pd.to_numeric(test['EMPLOYER_PHONE_EXT'],
                  errors='coerce')
      .fillna(0)
    )


 #Replacing NaN value in column with EMPLOYER_PHONE_EXT with 0
test['EMPLOYER_PHONE_EXT'].replace(0, np.nan, inplace= True)
#Replacing NaN value in column with EMPLOYER_PHONE with 0
test['EMPLOYER_PHONE'].replace(0, np.nan, inplace= True)

test['SUPPORT_H1B'].fillna(value=0,inplace=True)
test['EMPLOYER_PHONE'].isna().sum()
# we had 834 missing values i.e employer did not provide phone number which we are converting to 0
test['EMPLOYER_PHONE'].fillna(value=0,inplace=True)
#E_3 = train.loc[train['VISA_CLASS'] == 'E-3 Australian', ['CASE_STATUS']]
#E_3

test['AGENT_ATTORNEY_CITY'].fillna(value=0,inplace=True)
test['AGENT_ATTORNEY_STATE'].fillna(value=0,inplace=True)

test['EMPLOYER_PROVINCE'].fillna(value=0,inplace=True)
test['EMPLOYER_PHONE_EXT'].fillna(value=0,inplace=True)
test['EMPLOYER_BUSINESS_DBA'].fillna(value=0,inplace=True)
test['PW_WAGE_LEVEL'].fillna(value=0,inplace=True)
# We are replacing missing values with 0 for this column 
test['AGENT_REPRESENTING_EMPLOYER'].fillna(value=0,inplace=True)
# this step will replace all the column rows with Y and N to 1 and 0

train['EMPLOYER_PROVINCE'].fillna(value=0,inplace=True)

#COLUMNS TO BE DROPPED
test.drop('EMPLOYER_COUNTRY',axis=1,inplace=True)
test['LABOR_CON_AGREE'].fillna(value=0,inplace=True)
test.fillna(value=0,inplace=True)

# %%
msno.bar(trainwithoutduration)

# %%
cat_columns = train.select_dtypes(['object']).columns

for col in cat_columns:
    lbl = preprocessing.LabelEncoder()
    lbl.fit(list(train[col].values.astype('str')) + list(test[col].values.astype('str')))
    train[col] = lbl.transform(list(train[col].values.astype('str')))
    test[col] = lbl.transform(list(test[col].values.astype('str')))

# %%
wagerate = train.loc[train['WAGE_RATE_OF_PAY_TO'] >0 , ['EMPLOYER_NAME','CASE_STATUS','WAGE_RATE_OF_PAY_TO']]
wagerate.sort_values(by='WAGE_RATE_OF_PAY_TO',ascending=False)

# %%
topjobs=train['JOB_TITLE'].value_counts()
top15jobs=topjobs[:15]
top15jobs

# %%
top15jobs.plot.barh()

# %%
train.columns
# Out:
# Index(['Ob', 'CASE_STATUS', 'CASE_SUBMITTED', 'DECISION_DATE', 'VISA_CLASS',
#        'EMPLOYER_NAME', 'EMPLOYER_BUSINESS_DBA', 'EMPLOYER_ADDRESS',
#        'EMPLOYER_CITY', 'EMPLOYER_STATE', 'EMPLOYER_POSTAL_CODE',
#        'EMPLOYER_PROVINCE', 'EMPLOYER_PHONE', 'EMPLOYER_PHONE_EXT',
#        'AGENT_REPRESENTING_EMPLOYER', 'AGENT_ATTORNEY_NAME',
#        'AGENT_ATTORNEY_CITY', 'AGENT_ATTORNEY_STATE', 'JOB_TITLE', 'SOC_CODE',
#        'SOC_NAME', 'NAICS_CODE', 'TOTAL_WORKERS', 'NEW_EMPLOYMENT',
#        'CONTINUED_EMPLOYMENT', 'CHANGE_PREVIOUS_EMPLOYMENT',
#        'NEW_CONCURRENT_EMPLOYMENT', 'CHANGE_EMPLOYER', 'AMENDED_PETITION',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'PW_UNIT_OF_PAY',
#        'PW_WAGE_LEVEL', 'PW_SOURCE', 'PW_SOURCE_YEAR', 'PW_SOURCE_OTHER',
#        'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY',
#        'H1B_DEPENDENT', 'WILLFUL_VIOLATOR', 'SUPPORT_H1B', 'LABOR_CON_AGREE',
#        'WORKSITE_CITY', 'WORKSITE_COUNTY', 'WORKSITE_STATE',
#        'WORKSITE_POSTAL_CODE', 'ORIGINAL_CERT_DATE', 'Employment_duration',
#        'Processing_time'],
#       dtype='object')

# %%
obj_df=train.select_dtypes(include=['object']).copy

# %%
# %%time
# Impute 0 for missing target values



# label encode the categorical variables and convert the numerical variables to float

for col in cat_colum:
    print(col)
    lbl = preprocessing.LabelEncoder()
    lbl.fit(list(trainwithoutduration[col].values.astype('str')) + list(test[col].values.astype('str')))
    trainwithoutduration[col] = lbl.transform(list(trainwithoutduration[col].values.astype('str')))
    test[col] = lbl.transform(list(test[col].values.astype('str')))
# Out:
# VISA_CLASS
# EMPLOYER_NAME
# EMPLOYER_BUSINESS_DBA
# EMPLOYER_ADDRESS
# EMPLOYER_CITY
# EMPLOYER_STATE
# EMPLOYER_POSTAL_CODE
# EMPLOYER_PROVINCE
# EMPLOYER_PHONE
# EMPLOYER_PHONE_EXT
# AGENT_REPRESENTING_EMPLOYER
# AGENT_ATTORNEY_NAME
# AGENT_ATTORNEY_CITY
# AGENT_ATTORNEY_STATE
# JOB_TITLE
# SOC_CODE
# SOC_NAME
# FULL_TIME_POSITION
# PW_UNIT_OF_PAY
# PW_WAGE_LEVEL
# PW_SOURCE
# PW_SOURCE_OTHER
# WAGE_UNIT_OF_PAY
# H1B_DEPENDENT
# WILLFUL_VIOLATOR
# SUPPORT_H1B
# LABOR_CON_AGREE
# WORKSITE_CITY
# WORKSITE_COUNTY
# WORKSITE_STATE
# WORKSITE_POSTAL_CODE
# ORIGINAL_CERT_DATE
# CPU times: user 778 ms, sys: 25.9 ms, total: 804 ms
# Wall time: 802 ms

# %%
X=trainwithoutduration.iloc[:,1:]
y=trainwithoutduration.iloc[:,0]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
classifier=LogisticRegression(random_state=0)
classifier.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1846-b87b693245be> in <module>()
#       1 classifier=LogisticRegression(random_state=0)
# ----> 2 classifier.fit(X_train,y_train)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1221
#    1222         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype,
# -> 1223                          order="C")
#    1224         check_classification_targets(y)
#    1225         self.classes_ = np.unique(y)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
